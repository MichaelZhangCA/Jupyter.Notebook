# %%
import requests

# %%
data = requests.get('https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=MSFT&apikey=S1BJMI0DQNCAXEAO')
data
# Out:
# <Response [200]>

# %%
tsdata = data.json()['Time Series (Daily)']
tsdata
# Out:
# {'2017-08-31': {'1. open': '74.0300',
#   '2. high': '74.9600',
#   '3. low': '73.8000',
#   '4. close': '74.7700',
#   '5. adjusted close': '74.3935',
#   '6. volume': '26688077',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2017-09-01': {'1. open': '74.7100',
#   '2. high': '74.7400',
#   '3. low': '73.6400',
#   '4. close': '73.9400',
#   '5. adjusted close': '73.5676',
#   '6. volume': '21593192',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2017-09-05': {'1. open': '73.3400',
#   '2. high': '73.8900',
#   '3. low': '72.9800',
#   '4. close': '73.6100',
#   '5. adjusted close': '73.2393',
#   '6. volume': '21432599',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2017-09-06': {'1. open': '73.7400',
#   '2. high': '74.0400',
#   '3. low': '73.3500',
#   '4. close': '73.4000',
#   '5. adjusted close': '73.0304',
#   '6. volume': '15945136',
#   '7. dividend amount': '0.0000',
# ...

# %%
tsdata.keys()
# Out:
# dict_keys(['2018-01-24', '2018-01-23', '2018-01-22', '2018-01-19', '2018-01-18', '2018-01-17', '2018-01-16', '2018-01-12', '2018-01-11', '2018-01-10', '2018-01-09', '2018-01-08', '2018-01-05', '2018-01-04', '2018-01-03', '2018-01-02', '2017-12-29', '2017-12-28', '2017-12-27', '2017-12-26', '2017-12-22', '2017-12-21', '2017-12-20', '2017-12-19', '2017-12-18', '2017-12-15', '2017-12-14', '2017-12-13', '2017-12-12', '2017-12-11', '2017-12-08', '2017-12-07', '2017-12-06', '2017-12-05', '2017-12-04', '2017-12-01', '2017-11-30', '2017-11-29', '2017-11-28', '2017-11-27', '2017-11-24', '2017-11-22', '2017-11-21', '2017-11-20', '2017-11-17', '2017-11-16', '2017-11-15', '2017-11-14', '2017-11-13', '2017-11-10', '2017-11-09', '2017-11-08', '2017-11-07', '2017-11-06', '2017-11-03', '2017-11-02', '2017-11-01', '2017-10-31', '2017-10-30', '2017-10-27', '2017-10-26', '2017-10-25', '2017-10-24', '2017-10-23', '2017-10-20', '2017-10-19', '2017-10-18', '2017-10-17', '2017-10-16', '2017-10-13', '2017-1
# ...

# %%
list(tsdata.keys())
# Out:
# ['2018-01-24',
#  '2018-01-23',
#  '2018-01-22',
#  '2018-01-19',
#  '2018-01-18',
#  '2018-01-17',
#  '2018-01-16',
#  '2018-01-12',
#  '2018-01-11',
#  '2018-01-10',
#  '2018-01-09',
#  '2018-01-08',
#  '2018-01-05',
#  '2018-01-04',
#  '2018-01-03',
#  '2018-01-02',
#  '2017-12-29',
#  '2017-12-28',
#  '2017-12-27',
#  '2017-12-26',
#  '2017-12-22',
#  '2017-12-21',
#  '2017-12-20',
#  '2017-12-19',
#  '2017-12-18',
#  '2017-12-15',
#  '2017-12-14',
#  '2017-12-13',
#  '2017-12-12',
#  '2017-12-11',
#  '2017-12-08',
#  '2017-12-07',
#  '2017-12-06',
#  '2017-12-05',
#  '2017-12-04',
#  '2017-12-01',
#  '2017-11-30',
#  '2017-11-29',
#  '2017-11-28',
#  '2017-11-27',
#  '2017-11-24',
#  '2017-11-22',
#  '2017-11-21',
#  '2017-11-20',
#  '2017-11-17',
#  '2017-11-16',
#  '2017-11-15',
#  '2017-11-14',
#  '2017-11-13',
#  '2017-11-10',
#  '2017-11-09',
#  '2017-11-08',
#  '2017-11-07',
#  '2017-11-06',
#  '2017-11-03',
#  '2017-11-02',
#  '2017-11-01',
#  '2017-10-31',
# ...

# %%
tsdata.get('2018-01-24')
# Out:
# {'1. open': '92.5500',
#  '2. high': '93.4300',
#  '3. low': '91.5800',
#  '4. close': '91.8200',
#  '5. adjusted close': '91.8200',
#  '6. volume': '32734191',
#  '7. dividend amount': '0.0000',
#  '8. split coefficient': '1.0000'}

# %%
for key, value in tsdata.items():
    print (value)
# Out:
# {'1. open': '92.5500', '2. high': '93.4300', '3. low': '91.5800', '4. close': '91.8200', '5. adjusted close': '91.8200', '6. volume': '32734191', '7. dividend amount': '0.0000', '8. split coefficient': '1.0000'}
# {'1. open': '91.9000', '2. high': '92.3000', '3. low': '91.5400', '4. close': '91.9000', '5. adjusted close': '91.9000', '6. volume': '22283365', '7. dividend amount': '0.0000', '8. split coefficient': '1.0000'}
# {'1. open': '90.0000', '2. high': '91.6200', '3. low': '89.7400', '4. close': '91.6100', '5. adjusted close': '91.6100', '6. volume': '23190700', '7. dividend amount': '0.0000', '8. split coefficient': '1.0000'}
# {'1. open': '90.1400', '2. high': '90.6100', '3. low': '89.6600', '4. close': '90.0000', '5. adjusted close': '90.0000', '6. volume': '34896964', '7. dividend amount': '0.0000', '8. split coefficient': '1.0000'}
# ...

# %%
tsdata
# Out:
# {'2017-08-31': {'1. open': '74.0300',
#   '2. high': '74.9600',
#   '3. low': '73.8000',
#   '4. close': '74.7700',
#   '5. adjusted close': '74.3935',
#   '6. volume': '26688077',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2017-09-01': {'1. open': '74.7100',
#   '2. high': '74.7400',
#   '3. low': '73.6400',
#   '4. close': '73.9400',
#   '5. adjusted close': '73.5676',
#   '6. volume': '21593192',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2017-09-05': {'1. open': '73.3400',
#   '2. high': '73.8900',
#   '3. low': '72.9800',
#   '4. close': '73.6100',
#   '5. adjusted close': '73.2393',
#   '6. volume': '21432599',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2017-09-06': {'1. open': '73.7400',
#   '2. high': '74.0400',
#   '3. low': '73.3500',
#   '4. close': '73.4000',
#   '5. adjusted close': '73.0304',
#   '6. volume': '15945136',
#   '7. dividend amount': '0.0000',
# ...
