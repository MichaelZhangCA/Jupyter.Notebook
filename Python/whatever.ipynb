# %%
import quandl

# %%
quandl.ApiConfig.api_key = "dygSncwD1VTudYKz9UNb"
mydata = quandl.get("WIKI/MMM", start_date='2017-01-01')
mydata
# Out:
#               Open      High       Low   Close     Volume  Ex-Dividend  \
# Date
# 2017-01-03  178.83  180.0000  177.2200  178.05  2510055.0          0.0
# 2017-01-04  178.03  178.9000  177.6100  178.32  1541985.0          0.0
# 2017-01-05  178.26  179.1400  176.8900  177.71  1447568.0          0.0
# 2017-01-06  177.29  178.6000  175.8000  178.23  1625049.0          0.0
# 2017-01-09  178.37  178.3800  177.2000  177.27  1622625.0          0.0
# 2017-01-10  177.36  177.4900  176.3101  176.58  2030149.0          0.0
# 2017-01-11  176.63  178.4500  176.3900  177.89  1579593.0          0.0
# 2017-01-12  176.97  177.7000  175.7500  177.44  1321766.0          0.0
# 2017-01-13  177.58  177.9100  176.8300  177.39  1265593.0          0.0
# 2017-01-17  177.00  177.6800  176.2500  177.26  1557453.0          0.0
# 2017-01-18  177.90  179.4400  177.3800  178.49  1804904.0          0.0
# 2017-01-19  179.25  179.8000  177.7600  178.68  1464364.0          0.0
# ...

# %%
for row in mydata:
    print(row)
    break
# Out:
# Open

# %%
mydata.empty
# dic = mydata.to_dict('index')
mydata.index.min()
# Out:
# Timestamp('2017-01-03 00:00:00')

# %%
for key, his in dic.items():
    print (key)
    break
# Out:
# 1980-12-12 00:00:00

# %%
import datetime
import pandas as pd
from pandas.tseries.offsets import BDay

TBD1 = pd.datetime.today() - BDay(1)
tbd = TBD1.to_pydatetime().date()

# %%
from datetime import timedelta
tbd + timedelta(days=1)
# Out:
# datetime.date(2018, 1, 27)

# %%
print("""  ! Got error when dumping : {0}, error : {1}""".format('aaa', """bb with \'some strange strings\''"""))
# Out:
#   ! Got error when dumping : aaa, error : bb with 'some strange strings''

# %%
import mysql.connector
cnx = mysql.connector.connect(user='michael', password='Password2017',
                              host='localhost',
                              database='stock_market')
cnx.autocommit = True
cur = cnx.cursor()
# cur.execute("select * from `ops.operation_log` limit 10")
cur.execute("INSERT INTO `stock_market`.`ops.operation_log` (`effective_date`, `service_name`, `action_name`, `serverity`, `log_message`) VALUES  ( current_date, 'test service', 'test action', %s, %s)", ('T',"'test 'message"))
# [row[0] for row in cur.fetchall()]
# cnx.commit()

# %%
# !where python
# Out:
# C:\Program Files\Python36\python.exe

# %%
# !where pip3
# Out:
# INFO: Could not find files for the given pattern(s).

# %%
# !python -m pip install mysql-connector==2.1.6

# %%
import sys
# -*- coding: utf-8 -*-

# Print iterations progress
def print_progress(iteration, total, prefix='', suffix='', decimals=1, bar_length=100):
    """
    Call in a loop to create terminal progress bar

    @params:
        iteration   - Required  : current iteration (Int)
        total       - Required  : total iterations (Int)
        prefix      - Optional  : prefix string (Str)
        suffix      - Optional  : suffix string (Str)
        decimals    - Optional  : positive number of decimals in percent complete (Int)
        bar_length  - Optional  : character length of bar (Int)
    """
    str_format = "{0:." + str(decimals) + "f}"
    percents = str_format.format(100 * (iteration / float(total)))
    filled_length = int(round(bar_length * iteration / float(total)))
    bar = '█' * filled_length + '-' * (bar_length - filled_length)

    sys.stdout.write('\r%s |%s| %s%s %s' % (prefix, bar, percents, '%', suffix)),

    if iteration == total:
        sys.stdout.write('\n')
    sys.stdout.flush()

# %%
print_progress(10,100)
# Out:
#  |██████████------------------------------------------------------------------------------------------| 10.0%

# %%
import time,sys

for i in range(100+1):
    time.sleep(0.1)
    print_progress(i,100)
    #sys.stdout.write(('='*i)+(''*(100-i))+("\r [ %d"%i+"% ] "))
    #sys.stdout.flush()
# Out:
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%

# %%
import datetime
from datetime import timedelta
(datetime.date.today() + timedelta(days=-7)) .strftime('%Y%m%d')
# Out:
# '20180213'

# %%
tt = ('1', 2)
tt[1]
# Out:
# 2
