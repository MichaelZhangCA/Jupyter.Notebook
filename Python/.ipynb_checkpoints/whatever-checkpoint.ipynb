# %%
import quandl

# %%
quandl.ApiConfig.api_key = "dygSncwD1VTudYKz9UNb"
mydata = quandl.get("WIKI/ASML")
mydata
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-63-bd71de732e8b> in <module>()
#       1 quandl.ApiConfig.api_key = "dygSncwD1VTudYKz9UNb"
# ----> 2 mydata = quandl.get("WIKI/AEM")
#       3 mydata
#
# C:\Program Files\Python36\lib\site-packages\quandl\get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# C:\Program Files\Python36\lib\site-packages\quandl\model\dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
# ...

# %%
for index, row in mydata.iterrows():
    print(row)
    break
# Out:
# Open           2.875000e+01
# High           2.887000e+01
# Low            2.875000e+01
# Close          2.875000e+01
# Volume         2.093900e+06
# Ex-Dividend    0.000000e+00
# Split Ratio    1.000000e+00
# Adj. Open      4.227059e-01
# Adj. High      4.244703e-01
# Adj. Low       4.227059e-01
# Adj. Close     4.227059e-01
# Adj. Volume    1.172584e+08
# Name: 1980-12-12 00:00:00, dtype: float64

# %%
dic = mydata.to_dict('index')
dic
# Out:
# {Timestamp('1980-12-12 00:00:00'): {'Adj. Close': 0.42270591588018,
#   'Adj. High': 0.42447025361603,
#   'Adj. Low': 0.42270591588018,
#   'Adj. Open': 0.42270591588018,
#   'Adj. Volume': 117258400.0,
#   'Close': 28.75,
#   'Ex-Dividend': 0.0,
#   'High': 28.87,
#   'Low': 28.75,
#   'Open': 28.75,
#   'Split Ratio': 1.0,
#   'Volume': 2093900.0},
#  Timestamp('1980-12-15 00:00:00'): {'Adj. Close': 0.40065169418209,
#   'Adj. High': 0.40256306006259,
#   'Adj. Low': 0.40065169418209,
#   'Adj. Open': 0.40256306006259,
#   'Adj. Volume': 43971200.0,
#   'Close': 27.25,
#   'Ex-Dividend': 0.0,
#   'High': 27.38,
#   'Low': 27.25,
#   'Open': 27.38,
#   'Split Ratio': 1.0,
#   'Volume': 785200.0},
#  Timestamp('1980-12-16 00:00:00'): {'Adj. Close': 0.37124606525129,
#   'Adj. High': 0.37301040298714,
#   'Adj. Low': 0.37124606525129,
#   'Adj. Open': 0.37301040298714,
#   'Adj. Volume': 26432000.0,
#   'Close': 25.25,
#   'Ex-Dividend': 0.0,
#   'High': 25.37,
#   'Low': 25.25,
# ...

# %%
for key, his in dic.items():
    print (key)
    break
# Out:
# 1980-12-12 00:00:00
